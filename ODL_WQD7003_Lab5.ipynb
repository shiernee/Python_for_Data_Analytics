# %% [markdown]
# # Welcome to WQD7003 Data Analytics Lab
# This code is generated for the purpose of WQD7003 module.
#
# Created by Shier Nee Saw
#
# Reference: Python for Data Analysis O'Reily

# %% [markdown]
# # Data Loading, Storage, and File

# %%
# Let’s start with a small comma-separated (CSV) text file:
# download nba.csv from ODL platform.
# upload to Google Colab: Refer to https://www.youtube.com/watch?v=I9zT-dC4Lw8&ab_channel=Dr.Vipin%27sClassroom
# after you have upload the file, run this cell

import pandas as pd

df = pd.read_csv('nba.csv')
df
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
# We could also have used read_table and specifying the delimiter:
df = pd.read_table('nba.csv', sep=',')
df
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
# if a file does not have header
# download nba_without_header.csv from ODL platform.
# upload to Google Colab: Refer to https://www.youtube.com/watch?v=I9zT-dC4Lw8&ab_channel=Dr.Vipin%27sClassroom
# after you have upload the file, run this cell

df = pd.read_csv('nba_without_header.csv', header=None)
df
# Out:
#                  0               1   2   3   4      5    6                  7  \
# 0    Avery Bradley  Boston Celtics   0  PG  25  6-Feb  180              Texas
# 1      Jae Crowder  Boston Celtics  99  SF  25  6-Jun  235          Marquette
# 2     John Holland  Boston Celtics  30  SG  27  6-May  205  Boston University
# 3      R.J. Hunter  Boston Celtics  28  SG  22  6-May  185      Georgia State
# 4    Jonas Jerebko  Boston Celtics   8  PF  29  6-Oct  231                NaN
# ..             ...             ...  ..  ..  ..    ...  ...                ...
# 452     Trey Lyles       Utah Jazz  41  PF  20  6-Oct  234           Kentucky
# 453   Shelvin Mack       Utah Jazz   8  PG  26  6-Mar  203             Butler
# 454      Raul Neto       Utah Jazz  25  PG  24  6-Jan  179                NaN
# 455   Tibor Pleiss       Utah Jazz  21   C  26  7-Mar  256                NaN
# 456    Jeff Withey       Utah Jazz  24   C  26    7-0  231             Kansas
#
#              8
# 0    7730337.0
# ...

# %%
# we can assign the header name

df = pd.read_csv('nba_without_header.csv',
                 names=['Name',	'Team'	'Number',	'Position',	'Age',	'Height',	'Weight',	'College',	'Salary'])
df
# Out:
#                          Name  TeamNumber Position  Age Height  Weight  \
# Avery Bradley  Boston Celtics           0       PG   25  6-Feb     180
# Jae Crowder    Boston Celtics          99       SF   25  6-Jun     235
# John Holland   Boston Celtics          30       SG   27  6-May     205
# R.J. Hunter    Boston Celtics          28       SG   22  6-May     185
# Jonas Jerebko  Boston Celtics           8       PF   29  6-Oct     231
# ...                       ...         ...      ...  ...    ...     ...
# Trey Lyles          Utah Jazz          41       PF   20  6-Oct     234
# Shelvin Mack        Utah Jazz           8       PG   26  6-Mar     203
# Raul Neto           Utah Jazz          25       PG   24  6-Jan     179
# Tibor Pleiss        Utah Jazz          21        C   26  7-Mar     256
# Jeff Withey         Utah Jazz          24        C   26    7-0     231
#
#                          College     Salary
# Avery Bradley              Texas  7730337.0
# ...

# %% [markdown]
# # Reading Text Files in Pieces
#
# When processing very large files or figuring out the right set of arguments to correctly process a large file, you may only want to read in a small piece of a file or iterate through smaller chunks of the file.

# %%
# read only the first 5 rows

df = pd.read_csv('nba.csv', nrows=5)
df
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %% [markdown]
# # Writing Data Out to Text Format
#
# Data can also be exported to delimited format. Let’s consider one of the CSV files read above:

# %%
# You should see a new file in the colab directory
# refer to https://www.youtube.com/watch?v=DAfNlCnFKwU&ab_channel=RKKeynotes

df = pd.read_csv('nba.csv', nrows=5)
df.to_csv('nba_write_csv.csv')
df.to_excel('nba_write_excel.xlsx')

# %%
# write series into csv
import numpy as np

dates = pd.date_range('1/1/2000', periods=7)
ts = pd.Series(np.arange(7), index=dates)
ts.to_csv('tseries.csv')

# %% [markdown]
# ## JSON Data
#
# JSON (short for JavaScript Object Notation) has become one of the standard formats for sending data by HTTP request between web browsers and other applications.
#
# It is a much more flexible data format than a tabular text form like CSV.
#
# JSON is very nearly valid Python code with the exception of its null value null and some other nuances (such as disallowing trailing commas at the end of lists).
#
# The basic types are objects (dicts), arrays (lists), strings, numbers, booleans, and nulls. All of the
# keys in an object must be strings. There are several Python libraries for reading and writing JSON data.

# %%
import json


# some JSON:
obj = """
{"name": "Wes",
"places_lived": ["United States", "Spain", "Germany"],
"pet": null,
"siblings": [{"name": "Scott", "age": 25, "pet": "Zuko"},
{"name": "Katie", "age": 33, "pet": "Cisco"}]
}
"""

result = json.loads(obj)

result  # result is a dict type
# Out:
# {'name': 'Wes',
#  'places_lived': ['United States', 'Spain', 'Germany'],
#  'pet': None,
#  'siblings': [{'name': 'Scott', 'age': 25, 'pet': 'Zuko'},
#   {'name': 'Katie', 'age': 33, 'pet': 'Cisco'}]}

# %%
result['name']
# Out:
# 'Wes'

# %%
result['places_lived']
# Out:
# ['United States', 'Spain', 'Germany']

# %%
# json.dumps on the other hand converts a Python object back to JSON:

asjson = json.dumps(result)
asjson
# Out:
# '{"name": "Wes", "places_lived": ["United States", "Spain", "Germany"], "pet": null, "siblings": [{"name": "Scott", "age": 25, "pet": "Zuko"}, {"name": "Katie", "age": 33, "pet": "Cisco"}]}'

# %%
# How you convert a JSON object or list of objects to a DataFrame or some other data
# structure for analysis will be up to you.
# Conveniently, you can pass a list of JSON objects
# to the DataFrame constructor and select a subset of the data fields:

siblings = pd.DataFrame(result['siblings'], columns=['name', 'age'])

siblings
# Out:
#     name  age
# 0  Scott   25
# 1  Katie   33

# %% [markdown]
# # Data Aggregation and Group Operations
#
# Categorizing a data set and applying a function to each group, whether an aggregation or transformation, is often a critical component of a data analysis workflow.
#
# After loading, merging, and preparing a data set, a familiar task is to compute group statistics or possibly pivot tables for reporting or visualization purposes. pandas provides a flexible and high-performance groupby facility, enabling you to slice and dice, and summarize data sets in a natural way.

# %% [markdown]
# In the first stage of the process, data contained in a pandas object, whether a Series, DataFrame, or otherwise, is split into groups based on one or more keys that you provide.
#
# The splitting is performed on a particular axis of an object. For example, a DataFrame can be grouped on its rows (axis=0) or its columns (axis=1). Once this is done, a function is applied to each group, producing a new value.
#
# Finally, the results of all those function applications are combined
# into a result object.

# %%
df = pd.DataFrame({'key1' : ['a', 'a', 'b', 'b', 'a'],
                   'key2' : ['one', 'two', 'one', 'two', 'one'],
                   'data1' : np.random.randn(5),
                   'data2' : np.random.randn(5)})

df
# Out:
#   key1 key2     data1     data2
# 0    a  one  0.673500 -0.034770
# 1    a  two -1.617976 -0.302566
# 2    b  one -0.505429 -1.098976
# 3    b  two  0.635437  2.427206
# 4    a  one -0.333970 -0.676530

# %% [markdown]
# Suppose you wanted to compute the mean of the data1 column using the groups labels from key1.
#
# There are a number of ways to do this.
#
# One is to access data1 and call groupby with the column (a Series) at key1

# %%
grouped = df['data1'].groupby(df['key1'])
grouped.mean()
# Out:
# key1
# a   -0.316452
# b    0.001327
# Name: data1, dtype: float64

# %%
grouped = df['data1'].groupby(df['key2'])
grouped.mean()
# Out:
# key2
# one   -0.05530
# two   -0.49127
# Name: data1, dtype: float64

# %%
# get the mean group by key 1 and key 2.
# output: the mean value for the instance with key 1 = a and key2 = one

means = df['data1'].groupby([df['key1'], df['key2']]).mean()
means
# Out:
# key1  key2
# a     one     0.169765
#       two    -1.617976
# b     one    -0.505429
#       two     0.635437
# Name: data1, dtype: float64

# %%
# Regardless of the objective in using groupby, a generally useful GroupBy method is
# size which return a Series containing group sizes:

df.groupby(['key1', 'key2']).size()
# Out:
# key1  key2
# a     one     2
#       two     1
# b     one     1
#       two     1
# dtype: int64

# %%
# return 90th percentile of data 1 group by key 1
grouped = df.groupby(['key1'])
grouped['data1'].quantile(0.9)
# Out:
# key1
# a    0.472006
# b    0.521350
# Name: data1, dtype: float64

# %%
# Provide description for grouped data
grouped.describe()
# Out:
#      data1                                                              \
#      count      mean       std       min       25%       50%       75%
# key1
# a      3.0 -0.426149  1.148516 -1.617976 -0.975973 -0.333970  0.169765
# b      2.0  0.065004  0.806714 -0.505429 -0.220213  0.065004  0.350220
#
#                data2                                                    \
#            max count      mean       std       min       25%       50%
# key1
# a     0.673500   3.0 -0.337955  0.322340 -0.676530 -0.489548 -0.302566
# b     0.635437   2.0  0.664115  2.493387 -1.098976 -0.217431  0.664115
#
#
#            75%       max
# key1
# a    -0.168668 -0.034770
# b     1.545661  2.427206

# %% [markdown]
# ## Iterating Over Groups
#
# The GroupBy object supports iteration, generating a sequence of 2-tuples containing the group name along with the chunk of data. Consider the following small example data set:

# %%
for name, group in df.groupby('key1'):
    print('name: ' + name)
    print('group')
    print(group)
    print('------')
# Out:
# name: a
# group
#   key1 key2     data1     data2
# 0    a  one  0.673500 -0.034770
# 1    a  two -1.617976 -0.302566
# 4    a  one -0.333970 -0.676530
# ------
# name: b
# group
#   key1 key2     data1     data2
# 2    b  one -0.505429 -1.098976
# 3    b  two  0.635437  2.427206
# ------

# %%
# In the case of multiple keys, the first element in the tuple will be a tuple of key values:

for (k1, k2), group in df.groupby(['key1', 'key2']):
    print('k1: ' + k1 + ' k2: ' + k2)
    print('group')
    print(group)
    print('-----')
# Out:
# k1: a k2: one
# group
#   key1 key2    data1    data2
# 0    a  one  0.67350 -0.03477
# 4    a  one -0.33397 -0.67653
# -----
# k1: a k2: two
# group
#   key1 key2     data1     data2
# 1    a  two -1.617976 -0.302566
# -----
# k1: b k2: one
# group
#   key1 key2     data1     data2
# 2    b  one -0.505429 -1.098976
# -----
# k1: b k2: two
# group
#   key1 key2     data1     data2
# 3    b  two  0.635437  2.427206
# -----

# %% [markdown]
# ## Selecting a Column or Subset of Columns
#
# Indexing a GroupBy object created from a DataFrame with a column name or array of column names has the effect of selecting those columns for aggregation.

# %%
# get the mean of data 2 group by key1 and key 2

df.groupby(['key1', 'key2'])[['data2']].mean()
# Out:
#               data2
# key1 key2
# a    one  -0.355650
#      two  -0.302566
# b    one  -1.098976
#      two   2.427206

# %% [markdown]
# ## Grouping with Dicts and Series

# %%
people = pd.DataFrame(np.random.randn(5, 5),
                      columns=['a', 'b', 'c', 'd', 'e'],
                      index=['Joe', 'Steve', 'Wes', 'Jim', 'Travis'])

people.iloc[2:3, 1:3] = np.nan   # assign some NaN values

people
# Out:
#                a         b         c         d         e
# Joe     0.063355  0.575413  1.406904 -0.341884 -2.061789
# Steve  -1.959428  1.016400 -0.304743 -0.328414  1.276370
# Wes     2.597324       NaN       NaN  2.208411 -0.435692
# Jim     0.425510  0.938266 -0.891109 -0.237224 -0.924431
# Travis -1.008278 -0.414532 -0.534236 -1.334906 -2.069301

# %% [markdown]
# Now, suppose I have a group correspondence for the columns and want to sum together the columns by group

# %%
mapping = {'a': 'red', 'b': 'red', 'c': 'blue',
           'd': 'blue', 'e': 'red', 'f' : 'orange'}

by_column = people.groupby(mapping, axis=1)
by_column.sum()
# Out:
#             blue       red
# Joe     1.065020 -1.423020
# Steve  -0.633157  0.333342
# Wes     2.208411  2.161632
# Jim    -1.128333  0.439345
# Travis -1.869142 -3.492110

# %% [markdown]
# ## Data Aggregation
#
# Using Python functions in what can be fairly creative ways is a more abstract way of defining a group mapping compared with a dict or Series.
#
# Any function passed as a group key will be called once per index value, with the return values being used as the group names. More concretely, consider the example DataFrame from the previous section, which has people’s first names as index values.
#
# Suppose you wanted to group by the length of the names; you could compute an array of string lengths, but instead you can just pass the len function:

# %%
people.groupby(len).sum()
# Out:
#           a         b         c         d         e
# 3  3.086189  1.513680  0.515795  1.629303 -3.421913
# 5 -1.959428  1.016400 -0.304743 -0.328414  1.276370
# 6 -1.008278 -0.414532 -0.534236 -1.334906 -2.069301

# %% [markdown]
# # XML and HTML: Web Scraping
#
# Python has many libraries for reading and writing data in the ubiquitous HTML and XML formats. lxml (http://lxml.de) is one that has consistently strong performance in
# parsing very large files.
#
# lxml has multiple programmer interfaces; first I’ll show using lxml.html for HTML, then parse some XML using lxml.objectify.
#
# Beautiful Soup is a Python library for parsing HTML and XML documents. It creates a parse tree from the document, allowing you to extract and manipulate data easily. Let's explore some basic and advanced usage of Beautiful Soup.
#
# Many websites make data available in HTML tables for viewing in a browser, but not downloadable as an easily machine-readable format like JSON, HTML, or XML.

# %%
# install neccesary libraries

# !pip install beautifulsoup4
# !pip install requests

# %%
# Import necessary libraries
import requests
from bs4 import BeautifulSoup

# Define the URL of the webpage to scrape
url = 'https://openai.com/'

# Send a GET request to the URL
response = requests.get(url)

# Parse the HTML content of the webpage
soup = BeautifulSoup(response.text, 'html.parser')

# Find the title tag and extract its text
title = soup.title.text

# Print the title
print("Title of the webpage:", title)
# Out:
# Title of the webpage: OpenAI

# %% [markdown]
# You can customize your scraping by exploring the HTML structure of the webpage and using different methods provided by Beautiful Soup to extract the data you need. Some common methods include find(), find_all(), select(), etc.

# %% [markdown]
# #### Scrap data from kdnuggets.com
# Reference: https://www.kdnuggets.com/2023/04/stepbystep-guide-web-scraping-python-beautiful-soup.html

# %% [markdown]
# This script retrieves the entire HTML content from the specified URL. This content encompasses all text, paragraphs, anchor tags, divs, and other elements present on the page. Our subsequent objective is to parse this data and separate the text content from the tags.

# %%
url = "https://www.kdnuggets.com/"
res = requests.get(url)
htmlData = res.content
parsedData = BeautifulSoup(htmlData, "html.parser")
print(parsedData.prettify())

# %% [markdown]
# The tag object corresponds to a particular tag in the HTML document. It can extract a tag from the whole document and return the first found tag if multiple tags with the same name are present in the DOM.

# %%
soup = BeautifulSoup("<h1> Welcome to KDnuggets! </h1>", 'html.parser')
print(type(soup.h1))
# Out:
# <class 'bs4.element.Tag'>

# %% [markdown]
# It contains the text inside a tag in string format. Beautiful Soup uses the NavigableString object to store the texts of a tag.

# %%
soup = BeautifulSoup("<h1> Welcome to KDnuggets! </h1>", "html.parser")
print(soup.h1.string)
print(type(soup.h1.string))
# Out:
#  Welcome to KDnuggets!
# <class 'bs4.element.NavigableString'>

# %% [markdown]
# It reads the HTML comments that are present inside a tag. It is a special type of NavigableString.

# %%
soup = BeautifulSoup("<h1><!-- This is a comment --></h1>", "html.parser")
print(soup.h1.string)
print(type(soup.h1.string))
# Out:
#  This is a comment
# <class 'bs4.element.Comment'>

# %% [markdown]
# Now, we will extract the title, different tags, classes, lists, etc., from the parsed HTML content.

# %%
# Getting the title of the HTML page.
print(parsedData.title)
# Out:
# <title>Data Science, Machine Learning, AI &amp; Analytics - KDnuggets</title>

# %%
# Or, you can also print the title string only.
print(parsedData.title.string)
# Out:
# Data Science, Machine Learning, AI & Analytics - KDnuggets

# %% [markdown]
# These functions are useful when you want to search for a specific tag in the HTML content. Find() will give only the first occurrence of that tag, while find_all() will give all the occurrences of that tag. You can also iterate through them. Let’s see this with an example below.

# %%
h2 = parsedData.find('h2')
print(h2)
# Out:
# <h2>Latest Posts</h2>

# %%
H2s = parsedData.find_all("h2")
for h2 in H2s:
    print(h2)
# Out:
# <h2>Latest Posts</h2>
# <h2>More Recent Posts</h2>
# <h2 size="+1">Top Posts</h2>

# %% [markdown]
# This will return the complete tag, but if you want to print only the string, you can write like that.

# %%
h2 = parsedData.find('h2').text
print(h2)
# Out:
# Latest Posts

# %% [markdown]
# We can also get the class, id, type, href, etc., of a particular tag. For example, getting the links of all the anchor tags present.

# %%
anchors = parsedData.find_all("a")
for a in anchors:
    print(a["href"])

# %% [markdown]
# ### Find relevant element id
# *  Right-click on the element.
# *  Select Inspect or Inspect Element in the context menu.
# *  An inspector window opens with the HTML of the element highlighted.
# *  In the highlighted HTML, find the HTML ID or Name for that element.
#
# refer to https://support.demandbase.com/hc/en-us/articles/360058035472-Find-an-HTML-ID-or-Name

# %%
# We can also find specific elements by giving a particular id or a class name.
tags = parsedData.find_all("li", class_="li-has-thumb")
for tag in tags:
    print(tag.text)

# %% [markdown]
# # Exercise
# Scrap the product name and their price in this website:
#
# https://in.puma.com/in/en/collections/collections-football/collections-football-manchester-city-fc
#
# Create a DataFrame to store the information and export as csv file.
#
# Submit both ipynb in PDF and the csv file.

# %% [markdown]
# ### Submission: File > Print > As PDF > Submit in ODL Platform
# ### Make sure the answer is visible in PDF format.
# ### Deadline: 1 week after today class.
